# %%
import numpy as np
cricket_score=[10,12,15,100]
print(np.mean(cricket_score))
# Out:
# 34.25

# %%
import numpy as np
cricket_score=[10,12,15,100]
median_score=np.median(cricket_score)
print(f"Median:{median_score}")
# Out:
# Median:13.5

# %%
from statistics import mode
votes=[1,2,2,3,3,3,34]
most_common=mode(votes)
print(most_common)
# Out:
# 3

# %%
import numpy as np
tight_data=[60,70,80]
spread_data=[20,70,120]
print("tight std:",np.std(tight_data))
print("spread std:",np.std(spread_data))
# Out:
# tight std: 8.16496580927726
# spread std: 40.824829046386306

# %%
import random
#simulating random predictions
for i in range(5):
  prediction=random.choice(["spam","not spam"])
  print(f"Email{i+1}:{prediction}")
# Out:
# Email1:spam
# Email2:spam
# Email3:not spam
# Email4:not spam
# Email5:spam

# %%
import random
#simulate 10dice rolls
samples=[random.randint(1,6) for _ in range(10)]
print("samples rolls:",samples)
print("samples means:",sum (samples)/len(samples))
# Out:
# samples rolls: [5, 2, 2, 2, 2, 4, 5, 5, 4, 6]
# samples means: 3.7
