# %%
fruits=("apple", "banana","mango")
print(fruits[0])
# Out:
# apple

# %%
fruits=("apple", "banana","mango")
print(fruits[1])
# Out:
# banana

# %%
fruits=("apple", "banana","mango")
print(fruits[2])
# Out:
# mango

# %%
students=[]
students.append("Rahul")
students.append("Ayesh")
print(students)
# Out:
# ['Rahul', 'Ayesh']

# %%
students=[]
students.append("Dattukumar")
students.append("Lingu")
print(students)
# Out:
# ['Dattukumar', 'Lingu']

# %%
Coordinates=(10,20)
print(Coordinates[1])
# Out:
# 20

# %%
Coordinates=(10,20)
print(Coordinates[0])
# Out:
# 10

# %%
numbers={1,2,3,3,2}
print(numbers)
# Out:
# {1, 2, 3}

# %%
numbers={1,2,3,4,5,5,6,6,2,1,3,4}
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
student={
    "name":"lingu",
    "age":25,
    "course":"B.sc agriculture"
}
print(student["name"])
# Out:
# lingu

# %%
student={
    "name":"lingu",
    "age":25,
    "course":"B.sc agriculture"
}
print(student["course"])
# Out:
# B.sc agriculture

# %%
student={
    "name":"lingu",
    "age":25,
    "course":"B.sc agriculture"
}
print(student["age"])
# Out:
# 25

# %%
student={
    "name":"Dattu",
    "age":25,
    "course":"B.sc(Hons) Agri business Management"
}
print(student["name"])
# Out:
# Dattu

# %%
student={
    "name":"Dattu",
    "age":25,
    "course":"B.sc(Hons) Agri business Management"
}
print(student["age"])
# Out:
# 25

# %%
student={
    "name":"Dattu",
    "age":25,
    "course":"B.sc(Hons) Agri business Management"
}
print(student["course"])
# Out:
# B.sc(Hons) Agri business Management

# %%
marks={
    "animal husbendry":95,
    "horticulture":97,
    "pathalogy":92,
    "entomlogy":95,
}
marks["agronomy"]=99
print(marks)
# Out:
# {'animal husbendry': 95, 'horticulture': 97, 'pathalogy': 92, 'entomlogy': 95, 'agronomy': 99}

# %%
marks={
    "animal husbendry":85,
    "horticulture":89,
    "pathalogy":84,
    "entomlogy":86,
}
marks["agronomy"]=82
print(marks)
# Out:
# {'animal husbendry': 85, 'horticulture': 89, 'pathalogy': 84, 'entomlogy': 86, 'agronomy': 82}
