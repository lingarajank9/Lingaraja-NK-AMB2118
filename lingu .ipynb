# %%
pest = int(input("Enter pest level(as a percentage,e.g.,5 for 5%):"))
damage=int(input("Enter damage level(as a percentage,e.g., 10 for 10%):"))
tempeture=int(input("Enter temperature(e.g.,25):"))
humidity=int(input("Enter humidity(as a percentage,e.g., 70 for70%):"))
# Out:
# Enter pest level(as a percentage,e.g.,5 for 5%):25
# Enter damage level(as a percentage,e.g., 10 for 10%):10
# Enter temperature(e.g.,25):37
# Enter humidity(as a percentage,e.g., 70 for70%):10

# %%
print("Recommendation: monitor daily,consider targeted pesticide spray if severity increases")
print("cost of interventaion:$500/ha")
if pest<5:
  print("Severity:low")
elif 5<=pest<=15:
  print("severity:medium")
else:
  print("Severity:high")
  harvest=int(input("enter day sowing:"))
  dayssowing=int(input("enter day sowing:"))
  print(f"harvest level:{harvest}")
  print(f"day:{dayssowing}")
# Out:
# Recommendation: monitor daily,consider targeted pesticide spray if severity increases
# cost of interventaion:$500/ha
# Severity:high
# enter day sowing:10
# enter day sowing:15
# harvest level:10
# day:15

# %%
r=int(input("enter rainfall"))
print("Rainfall:", r)
if r>50:
  print("delay planting, do field preparation")
  t=int(input("enter tempurature"))
  print("Tempurature:",t)
  if t>38:
    print("Delay activities, focus on irrigation")
    w=int(input("enter wind speed"))
    print("Windpeed:",w)
    if w>40:
      print("Cancel spray operations")
    else:
      print("Go ahead with planned activities")
# Out:
# enter rainfall35
# Rainfall: 35

# %%
crop=int(input("enter soil moisture level"))
print(f"soil moisture level:{crop}")
if crop<=40:
  print("crop:wheat\ntemperature=high\ndecision=irrigate immediately\nestimated water need=60mm\nreason=soil threshold level moisture=35%")
  elif crop<=50:
    print("crop:rice,\ntemperature=moderate\ndecision=irrigate now\n reason=soil threshold level moisture=35%")
