# %%
mark1=40
mark2=40
mark3=40
total=(mark1+mark2+mark3)
average=total/3
print("total=",total)
print("average=",average)
# Out:
# total= 120
# average= 40.0

# %%
mark=int(input("enter mark"))
if mark>=90:
  print("grade A")
elif mark>=75:
  print("grade B")
else:
  print("grade C")
# Out:
# enter mark40
# grade C

# %%
number=int(input("enter a number;"))
if number%2==0:
  print("number is even")
else:
  print("number is odd")
# Out:
# enter a number;37
# number is odd

# %%
age=int(input("enter a age:"))
 if age <12 and age >60
  print("discount ")
 else:
  print("no discount")
# Out:
#   File "/tmp/ipython-input-2088504480.py", line 2
#     if age <12 and age >60
#     ^
# IndentationError: unexpected indent

# %%
x=5
y=2
z=x+y*3
print(z)
# Out:
# 11

# %%
base_fee=int(input("enter base price"))
age=int(input("enter age"))
if age<12:
   fee=base_fee*0.5
elif age>60:
    fee=base_fee*0.3
else:
    fee=base_fee
    print("fee=",fee)
# Out:
# enter base price5000
# enter age22
# fee= 5000

# %%
a=10
b=a-3
a=a+1
print(a,b)
# Out:
# 11 7

# %%
year=int(input("enter year"))
if year%4==0:
  print("leap year")
else:
  print("not a leap year")
# Out:
# enter year2004
# leap year

# %%
n=int(input("enter n:"))
total=0
for i in range(1,n+1):
  total=total+i
print("total=",total)
# Out:
# enter n:5
# total= 15

# %%
rows=int(input("enter rows:"))
for i in range(1,rows+2):
  print("*"*i)
# Out:
# enter rows:2
# *
# **
# ***
