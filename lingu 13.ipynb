# %%
fruits=["apple","papaya","mango","banana",]
vegetables=["potato","okra","onion","carrot"]
append = fruits.append("orange")
remove= vegetables.remove("okra")
sort= fruits.sort(),vegetables.sort()
print(fruits[2],vegetables[2])
# Out:
# mango potato

# %%
coordinate=(20,30)
print(coordinate[1])
# Out:
# 30

# %%
numbers={1,3,5,4,7,4,5,8,8,3,7,1,2}
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 7, 8}

# %%
numbers={1,3,5,4,7,4,5,8,8,3,7,1,2}
numbers.add(8)
numbers.remove(3)
print(numbers)
# Out:
# {1, 2, 4, 5, 7, 8}

# %%
marks={
    "maths":85,
    "science":90
}
marks["maths"]=95
print(marks)
# Out:
# {'maths': 95, 'science': 90}
