# %%
name="karnataka"
print(len(name))
# Out:
# 9

# %%
word="HARI"
print((word[-1]),(word[-2]),(word[-3]),(word[-4]))
# Out:
# I R A H

# %%
s = input("Enter a string: ")
print("Length of the string:", len(s))
# Out:
# Enter a string: bhoomika
# Length of the string: 8

# %%
s = input("Enter a string: ")
rev = ""

for ch in s:
    rev = ch + rev

print("Reversed string:", rev)
# Out:
# Enter a string: vijaynagara
# Reversed string: araganyajiv

# %%
s = input("Enter a string: ")
rev = s[::-1]

if s == rev:
    print("Palindrome")
else:
    print("Not a Palindrome")
# Out:
# Enter a string: gadag
# Palindrome

# %%
s = input("Enter a string: ")
result = ""

for ch in s:
    if 'a' <= ch <= 'z':
        result += chr(ord(ch) - 32)
    else:
        result += ch

print("Uppercase string:", result)
# Out:
# Enter a string: microbiology
# Uppercase string: MICROBIOLOGY

# %%
numbers = list(map(int, input("Enter numbers: ").split()))

n = len(numbers) + 1
expected_sum = n * (n + 1) // 2
actual_sum = sum(numbers)

missing_number = expected_sum - actual_sum
print("Missing number:", missing_number)
# Out:
# Enter numbers: 4 6
# Missing number: -4

# %%
numbers = list(map(int, input("Enter numbers separated by space: ").split()))

for i in range(len(numbers)):
    if numbers[i] < 0:
        numbers[i] = 0

print("Updated list:", numbers)
# Out:
# Enter numbers separated by space: 5 7 -8 -6 -5 4 7
# Updated list: [5, 7, 0, 0, 0, 4, 7]

# %%
s = input("Enter a sentence: ")
words = s.split()
freq = {}

for w in words:
    freq[w] = freq.get(w, 0) + 1

print("Most frequent word:", max(freq, key=freq.get))
# Out:
# Enter a sentence: india is my country ,but wr is my entry
# Most frequent word: is

# %%
lst = list(map(int, input("Enter numbers: ").split()))
freq = {}

for num in lst:
    freq[num] = freq.get(num, 0) + 1

print(freq)
# Out:
# Enter numbers: 1 2 4 4 5 6 7 7 7
# {1: 1, 2: 1, 4: 2, 5: 1, 6: 1, 7: 3}

# %%
sentence = input("Enter a sentence: ")

vowels = "aeiouAEIOU"
words = sentence.split()

for word in words:
    count = 0
    for ch in word:
        if ch in vowels:
            count += 1
    print(word, ":", count)
# Out:
# Enter a sentence: i am a frustated guy
# i : 1
# am : 1
# a : 1
# frustated : 3
# guy : 1
