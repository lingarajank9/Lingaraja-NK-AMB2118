# %%
name="karnataka"
print(len(name))
# Out:
# 9

# %%
word="gkvk"
print((word[-1]),(word[-2]),(word[-3]),(word[-4]))
# Out:
# k v k g

# %%
name=str(input("enter a name"))
reversed_name = name[::-1]
if(reversed_name==name):
  print("it is a palindrome")
else:
  print("it is not a palindrome")
# Out:
# enter a namegadag
# it is a palindrome

# %%
name="bhagavan"
print(name.replace("bhagavan","BHAGAVAN"))
# Out:
# BHAGAVAN

# %%
list_1={2,0,3,2}
list_2={2,0,0,3}
print(set(list_1)&set(list_2))
# Out:
# {0, 2, 3}
