# %%
nitrogen = int(input("enter the soil nitrogen level in mg/kg:"))
if nitrogen<100:
   print("application of high nitrogen fertilizers\n cost:rs.2000/kg")
   print("message:freqent apply of nitrogen fertilizers")
elif 100<=nitrogen<=250:
    print("apply medium nitrogen fertilizers\n cost:rs.1000/kg")
    print("message:soil has adequate nitrogen but need supplemnents")
else:
    print("no fertilizers needed,soil is healthy")
# Out:
# enter the soil nitrogen level in mg/kg:56
# application of high nitrogen fertilizers
#  cost:rs.2000/kg
# message:freqent apply of nitrogen fertilizers

# %%
    crop = input("Enter the crop (rice, wheat, sugarcane): ").lower()

    moisture = float(input("Enter soil moisture percentage: "))

    temp = input("Enter temperature condition (hot, moderate, cool): ").lower()

    if crop == "rice":
        if (temp == "hot" and moisture < 60) or (temp in ["moderate", "cool"] and moisture < 50):
            print("Rice needs water.")
        else:
            print("Rice does not need water.")

    elif crop == "wheat":
        if (temp == "hot" and moisture < 40) or (temp in ["moderate", "cool"] and moisture < 50):
            print("Wheat needs water.")
        else:
            print("Wheat does not need water.")

    elif crop == "sugarcane":
        if (temp == "hot" and moisture < 70) or (temp in ["moderate", "cool"] and moisture < 60):
            print("Sugarcane needs water.")
        else:
            print("Sugarcane does not need water.")

    else:
        print("Invalid crop type entered.")
# Out:
# Enter the crop (rice, wheat, sugarcane): rice
# Enter soil moisture percentage: 60
# Enter temperature condition (hot, moderate, cool): hot
# Rice does not need water.
